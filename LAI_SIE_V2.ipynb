# %% [markdown]
# Spectral Information Extraction<br>
# This script is used to extract information from image containing spectral bands for building the relationship between LAI and vegetation indices.<br>
# Required inputs:<br>
# > (1) Grids in one shapefile;<br>
# > (2) The image with spectral bands.
#
# The output is a table in "*.csv" format, and it contains the Grid 'FID' (starts from 1 instead of 0, not ID), the average value for each 6 bands, and the fractional cover.<br>
# Contact information:<br>
# Rui Gao<br>
# rui.gao@aggiemail.usu.edu

# %%
import arcpy
import arcview
from arcpy import env
import os
import gdal
import shutil
import numpy as np
import pandas as pd
import shapefile
import matplotlib.pyplot as plt
import datetime
# Out:
# C:\Users\grui9\anaconda3\envs\TSEB\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Product and extension licensing is no longer handled with this method.

# %%
def FolderCreate(NewFolderPath):
    if not os.path.exists(NewFolderPath):
        os.makedirs(NewFolderPath)

# %% [markdown]
# # The number of ground LAI measurements

# %%
LAI_Grids = r'D:\Project_Wellsville\7_LAI_VIs_Relation_1_meter_Grid\1_Coordinates_Ground_Measurements\2_ArcGIS_Grids\5R_0904.shp'
shp_info = shapefile.Reader(LAI_Grids)
records = shp_info.records()
num_records = len(records)
print("Totally",num_records,"ground LAI measurements.")
# Out:
# Totally 345 ground LAI measurements.

# %% [markdown]
# # Parameters, path setting

# %%
# information about the shapefile
dir_tmp = r'D:\Project_Wellsville\7_LAI_VIs_Relation_1_meter_Grid\1_Coordinates_Ground_Measurements\3_Extraction\5R_0904'
FolderCreate(dir_tmp)
arcpy.env.overwriteOutput = True
Shp_Grid_FileName = "FocusOnThisGrid.shp"
noDataValue = np.nan

# information about image. This image is resampled one (10 cm for my case)
dir_image = r'D:\Project_Wellsville\4_LAI_VI_Relationship\1_ArcGIS_Pro_Well\Clip_Raster.tif'

# %%
band_B = 0; band_G = 1; band_R = 2; band_RE = 3; band_NIR = 4; band_Tr = 5
ID = []
B = []
G = []
R = []
RE = []
NIR = []
Tr = []
fc = []
for ishp in range(num_records):
    env.workspace = LAI_Grids
    Shapefile = LAI_Grids.replace('.shp', '_lyr')
    arcpy.MakeFeatureLayer_management(LAI_Grids, Shapefile)
    arcpy.SelectLayerByAttribute_management(Shapefile, 'NEW_SELECTION', '"FID" =' + str(ishp))
    arcpy.CopyFeatures_management(Shapefile,
                                  dir_tmp + "\\" + Shp_Grid_FileName)
    
    # read the matrix for each location
    out_raster = arcpy.gp.ExtractByMask_sa(dir_image, dir_tmp + "\\" + Shp_Grid_FileName, 
                                           dir_tmp+"\\"+"GridID_"+str(ishp)+".tif")
    array_grid = arcpy.RasterToNumPyArray(dir_tmp+"\\"+"GridID_"+str(ishp)+".tif", 
                                          nodata_to_value=noDataValue)
    
    # calculate the fractional cover
    array_ndvi = (array_grid[band_NIR,:,:]-array_grid[band_R,:,:])/(array_grid[band_NIR,:,:]+array_grid[band_R,:,:])
    array_ndvi[array_ndvi>=0.4] = 1; array_ndvi[array_ndvi<1] = 0

    # get the average for each band
    ID.append(ishp+1)
    B.append(np.nanmean(array_grid[band_B,:,:]))
    G.append(np.nanmean(array_grid[band_G,:,:]))
    R.append(np.nanmean(array_grid[band_R,:,:]))
    RE.append(np.nanmean(array_grid[band_RE,:,:]))
    NIR.append(np.nanmean(array_grid[band_NIR,:,:]))
    Tr.append(np.nanmean(array_grid[band_Tr,:,:]))
    fc.append(np.nansum(array_ndvi)/(array_ndvi.shape[0]*array_ndvi.shape[1]))
    print("Processed:",str(ishp+1),'/',num_records)
# Out:
# Processed: 1 / 345
# Processed: 2 / 345
# Processed: 3 / 345
# Processed: 4 / 345
# Processed: 5 / 345
# Processed: 6 / 345
# Processed: 7 / 345
# Processed: 8 / 345
# Processed: 9 / 345
# Processed: 10 / 345
# Processed: 11 / 345
# Processed: 12 / 345
# Processed: 13 / 345
# Processed: 14 / 345
# Processed: 15 / 345
# Processed: 16 / 345
# Processed: 17 / 345
# Processed: 18 / 345
# Processed: 19 / 345
# Processed: 20 / 345
# Processed: 21 / 345
# Processed: 22 / 345
# Processed: 23 / 345
# Processed: 24 / 345
# Processed: 25 / 345
# Processed: 26 / 345
# Processed: 27 / 345
# Processed: 28 / 345
# Processed: 29 / 345
# Processed: 30 / 345
# Processed: 31 / 345
# Processed: 32 / 345
# Processed: 33 / 345
# Processed: 34 / 345
# Processed: 35 / 345
# Processed: 36 / 345
# Processed: 37 / 345
# Processed: 38 / 345
# Processed: 39 / 345
# Processed: 40 / 345
# Processed: 41 / 345
# Processed: 42 / 345
# Processed: 43 / 345
# Processed: 44 / 345
# Processed: 45 / 345
# Processed: 46 / 345
# Processed: 47 / 345
# Processed: 48 / 345
# Processed: 49 / 345
# Processed: 50 / 345
# Processed: 51 / 345
# Processed: 52 / 345
# Processed: 53 / 345
# Processed: 54 / 345
# Processed: 55 / 345
# Processed: 56 / 345
# Processed: 57 / 345
# Processed: 58 / 345
# Processed: 59 / 345
# Processed: 60 / 345
# Processed: 61 / 345
# Processed: 62 / 345
# Processed: 63 / 345
# Processed: 64 / 345
# Processed: 65 / 345
# Processed: 66 / 345
# Processed: 67 / 345
# Processed: 68 / 345
# Processed: 69 / 345
# Processed: 70 / 345
# Processed: 71 / 345
# Processed: 72 / 345
# Processed: 73 / 345
# Processed: 74 / 345
# Processed: 75 / 345
# Processed: 76 / 345
# Processed: 77 / 345
# Processed: 78 / 345
# Processed: 79 / 345
# Processed: 80 / 345
# Processed: 81 / 345
# Processed: 82 / 345
# Processed: 83 / 345
# Processed: 84 / 345
# Processed: 85 / 345
# Processed: 86 / 345
# Processed: 87 / 345
# Processed: 88 / 345
# Processed: 89 / 345
# Processed: 90 / 345
# Processed: 91 / 345
# Processed: 92 / 345
# Processed: 93 / 345
# Processed: 94 / 345
# Processed: 95 / 345
# Processed: 96 / 345
# Processed: 97 / 345
# Processed: 98 / 345
# Processed: 99 / 345
# Processed: 100 / 345
# Processed: 101 / 345
# Processed: 102 / 345
# Processed: 103 / 345
# Processed: 104 / 345
# Processed: 105 / 345
# Processed: 106 / 345
# Processed: 107 / 345
# Processed: 108 / 345
# Processed: 109 / 345
# Processed: 110 / 345
# Processed: 111 / 345
# Processed: 112 / 345
# Processed: 113 / 345
# Processed: 114 / 345
# Processed: 115 / 345
# Processed: 116 / 345
# Processed: 117 / 345
# Processed: 118 / 345
# Processed: 119 / 345
# Processed: 120 / 345
# Processed: 121 / 345
# Processed: 122 / 345
# Processed: 123 / 345
# Processed: 124 / 345
# Processed: 125 / 345
# Processed: 126 / 345
# Processed: 127 / 345
# Processed: 128 / 345
# Processed: 267 / 345
# Processed: 268 / 345
# Processed: 269 / 345
# Processed: 270 / 345
# Processed: 271 / 345
# Processed: 272 / 345
# Processed: 273 / 345
# Processed: 274 / 345
# Processed: 275 / 345
# Processed: 276 / 345
# Processed: 277 / 345
# Processed: 278 / 345
# Processed: 279 / 345
# Processed: 280 / 345
# Processed: 281 / 345
# Processed: 282 / 345
# Processed: 283 / 345
# Processed: 284 / 345
# Processed: 285 / 345
# Processed: 286 / 345
# Processed: 287 / 345
# Processed: 288 / 345
# Processed: 289 / 345
# Processed: 290 / 345
# Processed: 291 / 345
# Processed: 292 / 345
# Processed: 293 / 345
# Processed: 294 / 345
# Processed: 295 / 345
# Processed: 296 / 345
# Processed: 297 / 345
# Processed: 298 / 345
# Processed: 299 / 345
# Processed: 300 / 345
# Processed: 301 / 345
# Processed: 302 / 345
# Processed: 303 / 345
# Processed: 304 / 345
# Processed: 305 / 345
# Processed: 306 / 345
# Processed: 307 / 345
# Processed: 308 / 345
# Processed: 309 / 345
# Processed: 310 / 345
# Processed: 311 / 345
# Processed: 312 / 345
# Processed: 313 / 345
# Processed: 314 / 345
# Processed: 315 / 345
# Processed: 316 / 345
# Processed: 317 / 345
# Processed: 318 / 345
# Processed: 319 / 345
# Processed: 320 / 345
# Processed: 321 / 345
# Processed: 322 / 345
# Processed: 323 / 345
# Processed: 324 / 345
# Processed: 325 / 345
# Processed: 326 / 345
# Processed: 327 / 345
# Processed: 328 / 345
# Processed: 329 / 345
# Processed: 330 / 345
# Processed: 331 / 345
# Processed: 332 / 345
# Processed: 333 / 345
# Processed: 334 / 345
# Processed: 335 / 345
# Processed: 336 / 345
# Processed: 337 / 345
# Processed: 338 / 345
# Processed: 339 / 345
# Processed: 340 / 345
# Processed: 341 / 345
# Processed: 342 / 345
# Processed: 343 / 345
# Processed: 344 / 345
# Processed: 345 / 345

# %%
df_out = pd.DataFrame()
df_out['ID'] = ID
df_out['B'] = B
df_out['G'] = G
df_out['R'] = R
df_out['RE'] = RE
df_out['NIR'] = NIR
df_out['Tr'] = Tr
df_out['Fc'] = fc
df_out
df_out.to_csv(dir_tmp+'\\5R_0904.csv',index=False)

# %%
df_out
# Out:
#       ID         B         G         R        RE       NIR         Tr  \
# 0      1  0.020698  0.049003  0.025740  0.105043  0.544060  23.544512
# 1      2  0.025576  0.055462  0.030621  0.115797  0.564817  23.908310
# 2      3  0.030279  0.061788  0.038969  0.125242  0.503482  24.518408
# 3      4  0.021356  0.053820  0.023748  0.118030  0.567670  24.829609
# 4      5  0.022636  0.051324  0.030236  0.107112  0.420886  23.679209
# ..   ...       ...       ...       ...       ...       ...        ...
# 340  341  0.034647  0.079859  0.051428  0.198206  0.485735  27.342812
# 341  342  0.026583  0.065757  0.029603  0.170983  0.480150  25.488510
# 342  343  0.027490  0.067929  0.027781  0.177515  0.505579  24.407310
# 343  344  0.023598  0.063491  0.020511  0.175815  0.556593  23.949009
# 344  345  0.027409  0.067007  0.028921  0.175257  0.499838  24.451012
#
#            Fc
# 0    0.826446
# 1    0.826446
# 2    0.826446
# 3    0.826446
# 4    0.826446
# ..        ...
# 340  0.826446
# 341  0.826446
# 342  0.826446
# 343  0.826446
# 344  0.826446
#
# [345 rows x 8 columns]
